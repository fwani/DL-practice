# %%
# coding: utf-8
import sys, os
sys.path.append(os.pardir)  # 부모 디렉터리의 파일을 가져올 수 있도록 설정
import numpy as np
import matplotlib.pyplot as plt
from dataset.mnist import load_mnist
from simple_convnet import SimpleConvNet
from common.trainer import Trainer

# %%
# 데이터 읽기
(x_train, t_train), (x_test, t_test) = load_mnist(flatten=False)

# 시간이 오래 걸릴 경우 데이터를 줄인다.
#x_train, t_train = x_train[:5000], t_train[:5000]
#x_test, t_test = x_test[:1000], t_test[:1000]

max_epochs = 20

network = SimpleConvNet(input_dim=(1,28,28), 
                        conv_param = {'filter_num': 30, 'filter_size': 5, 'pad': 0, 'stride': 1},
                        hidden_size=100, output_size=10, weight_init_std=0.01)
                        
trainer = Trainer(network, x_train, t_train, x_test, t_test,
                  epochs=max_epochs, mini_batch_size=100,
                  optimizer='Adam', optimizer_param={'lr': 0.001},
                  evaluate_sample_num_per_epoch=1000)
trainer.train()

# 매개변수 보존
network.save_params("params.pkl")
print("Saved Network Parameters!")

# 그래프 그리기
markers = {'train': 'o', 'test': 's'}
x = np.arange(max_epochs)
plt.plot(x, trainer.train_acc_list, marker='o', label='train', markevery=2)
plt.plot(x, trainer.test_acc_list, marker='s', label='test', markevery=2)
plt.xlabel("epochs")
plt.ylabel("accuracy")
plt.ylim(0, 1.0)
plt.legend(loc='lower right')
plt.show()
# Out:
# train loss:2.299862146954559
# === epoch:1, train acc:0.163, test acc:0.128 ===
# train loss:2.2958866197701915
# train loss:2.2926047698262435
# train loss:2.2903396886863354
# train loss:2.2776196490646887
# train loss:2.261441405248318
# train loss:2.2598565500744097
# train loss:2.247031482543259
# train loss:2.232071702325417
# train loss:2.162209229015782
# train loss:2.1596846714626
# train loss:2.1200888291891613
# train loss:2.0915147005942423
# train loss:2.0672887388833097
# train loss:1.9886974141606815
# train loss:1.9104303411868153
# train loss:1.8281346270189016
# train loss:1.7152494895979922
# train loss:1.7071919747583393
# train loss:1.6214120816417534
# train loss:1.6236827109144878
# train loss:1.4671757947117678
# train loss:1.2766598867219596
# train loss:1.3781421884352252
# train loss:1.3198486048748064
# train loss:1.3503465759316495
# train loss:1.2250783963579848
# train loss:1.0690757254487273
# train loss:0.9157218796248414
# train loss:0.8927934625896694
# train loss:0.9926394488074426
# train loss:0.9333222444942423
# train loss:0.7897802028597773
# train loss:0.8318176462256771
# train loss:0.800906060593557
# train loss:0.6827012740338178
# train loss:0.7914408728793986
# train loss:0.8269571770622683
# train loss:0.7360760436169952
# train loss:0.7086552609447064
# train loss:0.8066143503452107
# train loss:0.6710435763172891
# train loss:0.7601067705594968
# train loss:0.6284113280247697
# train loss:0.6381255646292356
# train loss:0.8130791838168911
# train loss:0.6035974690125357
# train loss:0.723016978814163
# train loss:0.3891918439378824
# train loss:0.5303048484895568
# train loss:0.7038881872083432
# train loss:0.5530899206172076
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-5d086403362a> in <module>()
#      16                   optimizer='Adam', optimizer_param={'lr': 0.001},
#      17                   evaluate_sample_num_per_epoch=1000)
# ---> 18 trainer.train()
#      19
#      20 # 매개변수 보존
#
# ~\Desktop\Capstone\DL_Practice\deeplearning\common\trainer.py in train(self)
#      71         with tf.device("/gpu:0"):
#      72             for i in range(self.max_iter):
# ---> 73                 self.train_step()
#      74
#      75             test_acc = self.network.accuracy(self.x_test, self.t_test)
#
# ~\Desktop\Capstone\DL_Practice\deeplearning\common\trainer.py in train_step(self)
#      43         t_batch = self.t_train[batch_mask]
#      44
# ---> 45         grads = self.network.gradient(x_batch, t_batch)
#      46         self.optimizer.update(self.network.params, grads)
#      47
#
# ~\Desktop\Capstone\DL_Practice\deeplearning\ch07\simple_convnet.py in gradient(self, x, t)
#      48     def gradient(self, x, t):
#      49         #forward
# ---> 50         self.loss(x, t)
#      51
#      52         #backward
#
# ~\Desktop\Capstone\DL_Practice\deeplearning\ch07\simple_convnet.py in loss(self, x, t)
#      43
#      44     def loss(self, x, t):
# ---> 45         y = self.predict(x)
#      46         return self.last_layer.forward(y, t)
#      47
#
# ~\Desktop\Capstone\DL_Practice\deeplearning\ch07\simple_convnet.py in predict(self, x)
#      39     def predict(self, x):
#      40         for layer in self.layers.values():
# ---> 41             x = layer.forward(x)
#      42         return x
#      43
#
# ~\Desktop\Capstone\DL_Practice\deeplearning\common\layers.py in forward(self, x)
#      11     def forward(self, x):
#      12         self.mask = (x <= 0)
# ---> 13         out = x.copy()
#      14         out[self.mask] = 0
#      15
#
# KeyboardInterrupt:
