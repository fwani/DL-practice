# %%
import tensorflow as tf
import numpy as np

# %%
x_data = np.array([[0,0],[0,1],[1,0],[1,1]], dtype=np.float32)
y_data = np.array([[0],[1],[1],[0]], dtype=np.float32)

# %%
X = tf.placeholder(tf.float32)
Y = tf.placeholder(tf.float32)

W1 = tf.Variable(tf.random_normal([2,2]), name='weight1')
b1 = tf.Variable(tf.random_normal([2]), name='bias1')
layer1 = tf.sigmoid(tf.matmul(X, W1) + b1)

# %%
W2 = tf.Variable(tf.random_normal([2,1]), name='weight2')
b2 = tf.Variable(tf.random_normal([1]), name='bias2')
hypothesis = tf.sigmoid(tf.matmul(layer1, W2) + b2)

# %%
cost = -tf.reduce_mean(Y * tf.log(hypothesis) + (1 - Y) * tf.log(1 - hypothesis))
train = tf.train.GradientDescentOptimizer(learning_rate=0.1).minimize(cost)

# %%
predicted = tf.cast(hypothesis > 0.5, dtype=tf.float32)
accuracy = tf.reduce_mean(tf.cast(tf.equal(predicted, Y), dtype=tf.float32))

# %%
with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())
    
    for step in range(10001):
        sess.run(train, feed_dict={X: x_data, Y: y_data})
        if step % 100 == 0:
            print(step, sess.run(cost, feed_dict={X: x_data, Y: y_data}), sess.run([W1, W2]))
            
    h, c, a = sess.run([hypothesis, predicted, accuracy], feed_dict={X: x_data, Y: y_data})
    print("\nhypothesis: ", h, "\ncorrect: ", c, "\nAccuracy: ", a)
# Out:
# 0 0.69766945 [array([[ 0.4443969 , -0.04318921],
#        [-0.38094506,  0.34444326]], dtype=float32), array([[ 0.39369625],
#        [-0.71537375]], dtype=float32)]
# 100 0.69374573 [array([[ 0.42600912, -0.06121743],
#        [-0.3654588 ,  0.34720653]], dtype=float32), array([[ 0.31437463],
#        [-0.7676685 ]], dtype=float32)]
# 200 0.6936041 [array([[ 0.41220912, -0.08529643],
#        [-0.34898785,  0.34638515]], dtype=float32), array([[ 0.2969648],
#        [-0.7622635]], dtype=float32)]
# 300 0.6934786 [array([[ 0.3996386 , -0.10869036],
#        [-0.33379623,  0.34779355]], dtype=float32), array([[ 0.28122687],
#        [-0.7574561 ]], dtype=float32)]
# 400 0.69336456 [array([[ 0.38813585, -0.13156694],
#        [-0.3197358 ,  0.35133088]], dtype=float32), array([[ 0.2667071 ],
#        [-0.75344956]], dtype=float32)]
# 500 0.69325835 [array([[ 0.37757516, -0.1541091 ],
#        [-0.30667293,  0.3569006 ]], dtype=float32), array([[ 0.25327107],
#        [-0.75018984]], dtype=float32)]
# 600 0.69315684 [array([[ 0.36784914, -0.17648514],
#        [-0.2944929 ,  0.36443633]], dtype=float32), array([[ 0.24080993],
#        [-0.7476429 ]], dtype=float32)]
# 700 0.6930573 [array([[ 0.35886517, -0.19885235],
#        [-0.28309676,  0.3738988 ]], dtype=float32), array([[ 0.22923554],
#        [-0.74579227]], dtype=float32)]
# 800 0.6929573 [array([[ 0.35054258, -0.22136083],
#        [-0.27239802,  0.38527358]], dtype=float32), array([[ 0.21847683],
#        [-0.7446386 ]], dtype=float32)]
# 900 0.6928544 [array([[ 0.34281138, -0.24415638],
#        [-0.26232088,  0.39856994]], dtype=float32), array([[ 0.20847796],
#        [-0.74419826]], dtype=float32)]
# 1000 0.69274604 [array([[ 0.33560896, -0.26738417],
#        [-0.25279704,  0.41382024]], dtype=float32), array([[ 0.1991965],
#        [-0.744503 ]], dtype=float32)]
# 1100 0.69262993 [array([[ 0.3288794 , -0.2911916 ],
#        [-0.24376547,  0.43107972]], dtype=float32), array([[ 0.19060232],
#        [-0.7456007 ]], dtype=float32)]
# 1200 0.6925031 [array([[ 0.32257253, -0.315731  ],
#        [-0.2351699 ,  0.4504269 ]], dtype=float32), array([[ 0.18267685],
#        [-0.7475562 ]], dtype=float32)]
# 1300 0.69236237 [array([[ 0.31664258, -0.3411635 ],
#        [-0.22695804,  0.47196493]], dtype=float32), array([[ 0.17541258],
#        [-0.75045246]], dtype=float32)]
# 1400 0.69220424 [array([[ 0.31104732, -0.36766258],
#        [-0.21908031,  0.49582273]], dtype=float32), array([[ 0.16881347],
#        [-0.7543932 ]], dtype=float32)]
# 1500 0.6920241 [array([[ 0.3057466 , -0.39541787],
#        [-0.2114885 ,  0.52215767]], dtype=float32), array([[ 0.16289473],
#        [-0.7595047 ]], dtype=float32)]
# 1600 0.6918167 [array([[ 0.3007027 , -0.42463943],
#        [-0.20413502,  0.551158  ]], dtype=float32), array([[ 0.1576842 ],
#        [-0.76594096]], dtype=float32)]
# 1700 0.6915756 [array([[ 0.29587895, -0.4555628 ],
#        [-0.19697128,  0.5830453 ]], dtype=float32), array([[ 0.153223  ],
#        [-0.77388597]], dtype=float32)]
# 1800 0.69129264 [array([[ 0.291239  , -0.48845506],
#        [-0.1899466 ,  0.61808044]], dtype=float32), array([[ 0.14956698],
#        [-0.78355956]], dtype=float32)]
# 1900 0.69095767 [array([[ 0.28674594, -0.5236211 ],
#        [-0.18300696,  0.65656525]], dtype=float32), array([[ 0.1467886 ],
#        [-0.79522353]], dtype=float32)]
# 2000 0.69055796 [array([[ 0.28236163, -0.56141084],
#        [-0.17609264,  0.6988493 ]], dtype=float32), array([[ 0.14497942],
#        [-0.80918837]], dtype=float32)]
# 2100 0.69007695 [array([[ 0.27804598, -0.60222846],
#        [-0.16913663,  0.74533445]], dtype=float32), array([[ 0.14425184],
#        [-0.82582086]], dtype=float32)]
# 2200 0.6894945 [array([[ 0.2737554 , -0.64653975],
#        [-0.16206203,  0.79647934]], dtype=float32), array([[ 0.14474285],
#        [-0.8455519 ]], dtype=float32)]
# 2300 0.688784 [array([[ 0.26944125, -0.6948817 ],
#        [-0.15477864,  0.852804  ]], dtype=float32), array([[ 0.14661695],
#        [-0.8688868 ]], dtype=float32)]
# 2400 0.6879122 [array([[ 0.265049  , -0.7478699 ],
#        [-0.14717908,  0.9148924 ]], dtype=float32), array([[ 0.1500688 ],
#        [-0.89641166]], dtype=float32)]
# 2500 0.68683666 [array([[ 0.260516  , -0.8062038 ],
#        [-0.1391341 ,  0.98339117]], dtype=float32), array([[ 0.15532638],
#        [-0.9288007 ]], dtype=float32)]
# 2600 0.685504 [array([[ 0.25576842, -0.8706677 ],
#        [-0.13048607,  1.0590062 ]], dtype=float32), array([[ 0.16265276],
#        [-0.9668181 ]], dtype=float32)]
# 2700 0.683848 [array([[ 0.2507188 , -0.94211805],
#        [-0.1210421 ,  1.1424867 ]], dtype=float32), array([[ 0.17234588],
#        [-1.0113137 ]], dtype=float32)]
# 2800 0.68178785 [array([[ 0.24526182, -1.0214609 ],
#        [-0.11056476,  1.234603  ]], dtype=float32), array([[ 0.18473747],
#        [-1.0632071 ]], dtype=float32)]
# 2900 0.6792277 [array([[ 0.2392695 , -1.1096045 ],
#        [-0.09876262,  1.3361043 ]], dtype=float32), array([[ 0.20018664],
#        [-1.1234543 ]], dtype=float32)]
# 3000 0.676059 [array([[ 0.23258555, -1.2073824 ],
#        [-0.08528021,  1.4476577 ]], dtype=float32), array([[ 0.2190702],
#        [-1.1929926]], dtype=float32)]
# 3100 0.6721659 [array([[ 0.22501904, -1.3154503 ],
#        [-0.06968918,  1.5697671 ]], dtype=float32), array([[ 0.24177043],
#        [-1.2726601 ]], dtype=float32)]
# 3200 0.6674366 [array([[ 0.21633777, -1.4341532 ],
#        [-0.0514839 ,  1.7026689 ]], dtype=float32), array([[ 0.26865718],
#        [-1.363083  ]], dtype=float32)]
# 3300 0.6617801 [array([[ 0.20626302, -1.5633862 ],
#        [-0.03008539,  1.8462086 ]], dtype=float32), array([[ 0.3000702],
#        [-1.4645553]], dtype=float32)]
# 3400 0.65514684 [array([[ 0.19446759, -1.7024865 ],
#        [-0.004859  ,  1.9997394 ]], dtype=float32), array([[ 0.3363058],
#        [-1.5769192]], dtype=float32)]
# 3500 0.6475487 [array([[ 0.18057837, -1.8501896 ],
#        [ 0.02484968,  2.1620536 ]], dtype=float32), array([[ 0.37760723],
#        [-1.6994886 ]], dtype=float32)]
# 3600 0.63907003 [array([[ 0.1641857 , -2.0046873 ],
#        [ 0.05965889,  2.3313966 ]], dtype=float32), array([[ 0.4241662],
#        [-1.8310502]], dtype=float32)]
# 3700 0.62986517 [array([[ 0.14485691, -2.1637855 ],
#        [ 0.10007904,  2.505582  ]], dtype=float32), array([[ 0.47613233],
#        [-1.9699562 ]], dtype=float32)]
# 3800 0.62013865 [array([[ 0.12215136, -2.3251338 ],
#        [ 0.14643656,  2.6821995 ]], dtype=float32), array([[ 0.533632 ],
#        [-2.1142974]], dtype=float32)]
# 3900 0.6101148 [array([[ 0.09562775, -2.486459  ],
#        [ 0.19880918,  2.858853  ]], dtype=float32), array([[ 0.59678835],
#        [-2.2621176 ]], dtype=float32)]
# 4000 0.60000503 [array([[ 0.0648376, -2.6457682],
#        [ 0.256988 ,  3.0333884]], dtype=float32), array([[ 0.6657419],
#        [-2.4116058]], dtype=float32)]
# 4100 0.58998215 [array([[ 0.02929536, -2.8014722 ],
#        [ 0.32047403,  3.204041  ]], dtype=float32), array([[ 0.74067545],
#        [-2.561241  ]], dtype=float32)]
# 4200 0.5801642 [array([[-0.01158026, -2.9524403 ],
#        [ 0.38850796,  3.369512  ]], dtype=float32), array([[ 0.82184476],
#        [-2.7098565 ]], dtype=float32)]
# 4300 0.5706078 [array([[-0.05856163, -3.0979946 ],
#        [ 0.4601156 ,  3.528958  ]], dtype=float32), array([[ 0.9096311],
#        [-2.8566582]], dtype=float32)]
# 4400 0.5613052 [array([[-0.1127556 , -3.2378728 ],
#        [ 0.53415096,  3.6819386 ]], dtype=float32), array([[ 1.0046228],
#        [-3.0011961]], dtype=float32)]
# 4500 0.5521791 [array([[-0.1758188, -3.3721926],
#        [ 0.6093141,  3.8283405]], dtype=float32), array([[ 1.1077464],
#        [-3.143319 ]], dtype=float32)]
# 4600 0.54306495 [array([[-0.25028908, -3.5014355 ],
#        [ 0.68411964,  3.9683056 ]], dtype=float32), array([[ 1.2204818],
#        [-3.2831306]], dtype=float32)]
# 4700 0.53366995 [array([[-0.34011132, -3.6264856 ],
#        [ 0.7568273 ,  4.102151  ]], dtype=float32), array([[ 1.3452111],
#        [-3.4209177]], dtype=float32)]
# 4800 0.5234771 [array([[-0.45144376, -3.7487442 ],
#        [ 0.8254117 ,  4.2302995 ]], dtype=float32), array([[ 1.485824],
#        [-3.557055]], dtype=float32)]
# 4900 0.5115452 [array([[-0.5936632, -3.8703578],
#        [ 0.8879948,  4.3531656]], dtype=float32), array([[ 1.6486986],
#        [-3.691796 ]], dtype=float32)]
# 5000 0.49619433 [array([[-0.7794282, -3.994437 ],
#        [ 0.945281 ,  4.470962 ]], dtype=float32), array([[ 1.8438262],
#        [-3.8249705]], dtype=float32)]
# 5100 0.47497183 [array([[-1.0195985, -4.124608 ],
#        [ 1.0081962,  4.5834365]], dtype=float32), array([[ 2.0838528],
#        [-3.95629  ]], dtype=float32)]
# 5200 0.44596308 [array([[-1.3098803, -4.2625012],
#        [ 1.1067804,  4.6899714]], dtype=float32), array([[ 2.3764586],
#        [-4.088346 ]], dtype=float32)]
# 5300 0.40933216 [array([[-1.6271861, -4.404835 ],
#        [ 1.2741466,  4.790438 ]], dtype=float32), array([[ 2.71622  ],
#        [-4.2292743]], dtype=float32)]
# 5400 0.36690328 [array([[-1.9479209, -4.5454774],
#        [ 1.5124809,  4.885378 ]], dtype=float32), array([[ 3.0899763],
#        [-4.386132 ]], dtype=float32)]
# 5500 0.3220293 [array([[-2.257131 , -4.679541 ],
#        [ 1.7941893,  4.9751854]], dtype=float32), array([[ 3.4823432],
#        [-4.5586543]], dtype=float32)]
# 5600 0.27881116 [array([[-2.5453753, -4.80447  ],
#        [ 2.0859218,  5.0598397]], dtype=float32), array([[ 3.8760085],
#        [-4.74148  ]], dtype=float32)]
# 5700 0.24028832 [array([[-2.8072135, -4.91936  ],
#        [ 2.3637955,  5.1392107]], dtype=float32), array([[ 4.255358],
#        [-4.927994]], dtype=float32)]
# 5800 0.20766531 [array([[-3.0409684, -5.0242023],
#        [ 2.6161096,  5.2133136]], dtype=float32), array([[ 4.610211],
#        [-5.112639]], dtype=float32)]
# 5900 0.18077569 [array([[-3.247778 , -5.1194687],
#        [ 2.839852 ,  5.2823515]], dtype=float32), array([[ 4.9361935],
#        [-5.2917185]], dtype=float32)]
# 6000 0.15882626 [array([[-3.43029  , -5.2058997],
#        [ 3.0365133,  5.346668 ]], dtype=float32), array([[ 5.2330017],
#        [-5.4632244]], dtype=float32)]
# 6100 0.14089382 [array([[-3.591654 , -5.2843585],
#        [ 3.209295 ,  5.406641 ]], dtype=float32), array([[ 5.50251  ],
#        [-5.6263213]], dtype=float32)]
# 6200 0.12614608 [array([[-3.7349377, -5.35573  ],
#        [ 3.361691 ,  5.4626713]], dtype=float32), array([[ 5.747463],
#        [-5.780883]], dtype=float32)]
# 6300 0.11390371 [array([[-3.8628738, -5.420859 ],
#        [ 3.496905 ,  5.51513  ]], dtype=float32), array([[ 5.970773],
#        [-5.927176]], dtype=float32)]
# 6400 0.10363637 [array([[-3.977788 , -5.4805098],
#        [ 3.6176765,  5.5643587]], dtype=float32), array([[ 6.1751595],
#        [-6.065655 ]], dtype=float32)]
# 6500 0.09493647 [array([[-4.0816245, -5.535361 ],
#        [ 3.726276 ,  5.610665 ]], dtype=float32), array([[ 6.363047 ],
#        [-6.1968474]], dtype=float32)]
# 6600 0.08749178 [array([[-4.175998 , -5.5859995],
#        [ 3.8245637,  5.65432  ]], dtype=float32), array([[ 6.5365334],
#        [-6.3213005]], dtype=float32)]
# 6700 0.08106269 [array([[-4.2622347, -5.6329317],
#        [ 3.9140584,  5.695567 ]], dtype=float32), array([[ 6.69741 ],
#        [-6.439537]], dtype=float32)]
# 6800 0.07546358 [array([[-4.3414326, -5.6765904],
#        [ 3.9960015,  5.734623 ]], dtype=float32), array([[ 6.8471994],
#        [-6.55205  ]], dtype=float32)]
# 6900 0.07054953 [array([[-4.4145045, -5.7173505],
#        [ 4.071417 ,  5.7716765]], dtype=float32), array([[ 6.9871936],
#        [-6.6592937]], dtype=float32)]
# 7000 0.06620636 [array([[-4.482214 , -5.755532 ],
#        [ 4.1411443,  5.8068967]], dtype=float32), array([[ 7.118496 ],
#        [-6.7616806]], dtype=float32)]
# 7100 0.06234302 [array([[-4.545197 , -5.7914042],
#        [ 4.2058945,  5.8404336]], dtype=float32), array([[ 7.242046 ],
#        [-6.8595924]], dtype=float32)]
# 7200 0.058886424 [array([[-4.6039963, -5.825207 ],
#        [ 4.2662463,  5.8724256]], dtype=float32), array([[ 7.35865 ],
#        [-6.953365]], dtype=float32)]
# 7300 0.055777185 [array([[-4.659069 , -5.857145 ],
#        [ 4.3227024,  5.9029894]], dtype=float32), array([[ 7.4690027],
#        [-7.0433044]], dtype=float32)]
# 7400 0.05296681 [array([[-4.7108083, -5.887395 ],
#        [ 4.3756843,  5.9322352]], dtype=float32), array([[ 7.5737023],
#        [-7.1296864]], dtype=float32)]
# 7500 0.050415106 [array([[-4.7595534, -5.916114 ],
#        [ 4.425552 ,  5.960258 ]], dtype=float32), array([[ 7.6732726],
#        [-7.2127624]], dtype=float32)]
# 7600 0.04808876 [array([[-4.805594 , -5.943438 ],
#        [ 4.472619 ,  5.9871464]], dtype=float32), array([[ 7.7681713],
#        [-7.2927604]], dtype=float32)]
# 7700 0.045959763 [array([[-4.849187 , -5.9694853],
#        [ 4.5171514,  6.01298  ]], dtype=float32), array([[ 7.8587995],
#        [-7.369887 ]], dtype=float32)]
# 7800 0.04400453 [array([[-4.89055  , -5.994363 ],
#        [ 4.559385 ,  6.0378294]], dtype=float32), array([[ 7.945508 ],
#        [-7.4443283]], dtype=float32)]
# 7900 0.042203087 [array([[-4.929879 , -6.018164 ],
#        [ 4.5995226,  6.06176  ]], dtype=float32), array([[ 8.02861 ],
#        [-7.516253]], dtype=float32)]
# 8000 0.040538244 [array([[-4.967346 , -6.040972 ],
#        [ 4.6377454,  6.0848303]], dtype=float32), array([[ 8.108389],
#        [-7.585822]], dtype=float32)]
# 8100 0.038995344 [array([[-5.003101 , -6.0628605],
#        [ 4.6742105,  6.1070943]], dtype=float32), array([[ 8.185084 ],
#        [-7.6531744]], dtype=float32)]
# 8200 0.037561797 [array([[-5.03728  , -6.0838966],
#        [ 4.7090573,  6.1286025]], dtype=float32), array([[ 8.258922],
#        [-7.718441]], dtype=float32)]
# 8300 0.036226448 [array([[-5.0700035, -6.1041408],
#        [ 4.742414 ,  6.1493983]], dtype=float32), array([[ 8.3301   ],
#        [-7.7817397]], dtype=float32)]
# 8400 0.03497979 [array([[-5.1013803, -6.1236467],
#        [ 4.7743907,  6.169525 ]], dtype=float32), array([[ 8.398799 ],
#        [-7.8431816]], dtype=float32)]
# 8500 0.033813402 [array([[-5.1315064, -6.142463 ],
#        [ 4.8050866,  6.1890206]], dtype=float32), array([[ 8.465183],
#        [-7.902869]], dtype=float32)]
# 8600 0.032719854 [array([[-5.160466 , -6.1606355],
#        [ 4.8345923,  6.207918 ]], dtype=float32), array([[ 8.5294   ],
#        [-7.9608965]], dtype=float32)]
# 8700 0.031692713 [array([[-5.188341 , -6.178203 ],
#        [ 4.8629894,  6.226252 ]], dtype=float32), array([[ 8.591581],
#        [-8.017345]], dtype=float32)]
# 8800 0.030726142 [array([[-5.215201 , -6.1952033],
#        [ 4.8903513,  6.2440505]], dtype=float32), array([[ 8.65185 ],
#        [-8.072301]], dtype=float32)]
# 8900 0.029815141 [array([[-5.2411118, -6.21167  ],
#        [ 4.916744 ,  6.261343 ]], dtype=float32), array([[ 8.710317],
#        [-8.125833]], dtype=float32)]
# 9000 0.028954979 [array([[-5.266133 , -6.227633 ],
#        [ 4.9422283,  6.2781534]], dtype=float32), array([[ 8.767086],
#        [-8.178017]], dtype=float32)]
# 9100 0.028141685 [array([[-5.290319 , -6.2431207],
#        [ 4.9668603,  6.294507 ]], dtype=float32), array([[ 8.822251 ],
#        [-8.2289095]], dtype=float32)]
# 9200 0.027371507 [array([[-5.3137164, -6.258159 ],
#        [ 4.99069  ,  6.3104258]], dtype=float32), array([[ 8.8759  ],
#        [-8.278576]], dtype=float32)]
# 9300 0.026641186 [array([[-5.336373 , -6.272773 ],
#        [ 5.0137644,  6.32593  ]], dtype=float32), array([[ 8.928111],
#        [-8.327073]], dtype=float32)]
# 9400 0.025947787 [array([[-5.35833  , -6.2869835],
#        [ 5.036126 ,  6.3410406]], dtype=float32), array([[ 8.978958],
#        [-8.374449]], dtype=float32)]
# 9500 0.02528859 [array([[-5.379624 , -6.300812 ],
#        [ 5.0578127,  6.3557734]], dtype=float32), array([[ 9.028509 ],
#        [-8.4207535]], dtype=float32)]
# 9600 0.024661217 [array([[-5.4002924, -6.314277 ],
#        [ 5.078862 ,  6.370147 ]], dtype=float32), array([[ 9.076828],
#        [-8.466036]], dtype=float32)]
# 9700 0.02406331 [array([[-5.4203677, -6.327398 ],
#        [ 5.0993085,  6.384177 ]], dtype=float32), array([[ 9.123975],
#        [-8.510336]], dtype=float32)]
# 9800 0.023493025 [array([[-5.439881 , -6.3401885],
#        [ 5.11918  ,  6.397877 ]], dtype=float32), array([[ 9.170002],
#        [-8.553695]], dtype=float32)]
# 9900 0.022948444 [array([[-5.4588585, -6.3526664],
#        [ 5.1385083,  6.4112635]], dtype=float32), array([[ 9.214963],
#        [-8.596152]], dtype=float32)]
# 10000 0.022427846 [array([[-5.4773283, -6.364844 ],
#        [ 5.1573195,  6.4243464]], dtype=float32), array([[ 9.258905],
#        [-8.637742]], dtype=float32)]
#
# hypothesis:  [[0.02178523]
#  [0.97873676]
#  [0.9729028 ]
#  [0.01854756]]
# correct:  [[0.]
#  [1.]
#  [1.]
#  [0.]]
# Accuracy:  1.0
