# %%
import tensorflow as tf

# %% [markdown]
# # placeholder 예

# %%
a = tf.placeholder(tf.float32)
b = tf.placeholder(tf.float32)
adder_node = a + b
with tf.Session() as sess:
    print(sess.run(adder_node, feed_dict={a: 3, b: 4.5}))
    print(sess.run(adder_node, feed_dict={a: [1,3], b: [2,4]}))
# Out:
# 7.5
# [3. 7.]

# %% [markdown]
# # X, Y

# %%
X = tf.placeholder(tf.float32, shape=[None])
Y = tf.placeholder(tf.float32, shape=[None])

# %% [markdown]
# # variables

# %%
W = tf.Variable(tf.random_normal([1]), name='weight')
b = tf.Variable(tf.random_normal([1]), name='bias')

# %% [markdown]
# # Model

# %%
# Our hypothesis X * W + b
hypothesis = X * W + b  # W = 1  b = 0

# cost/loss function
cost = tf.reduce_mean(tf.square(hypothesis - Y))

# %% [markdown]
# # Minimize

# %%
optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.01)
train = optimizer.minimize(cost)

# %% [markdown]
# # Fit the line

# %%
sess = tf.Session()
# Launch the graph in a session.
sess = tf.Session()
# Initializes global variables in the graph.
sess.run(tf.global_variables_initializer())

for step in range(2001):
    cost_val, W_val, b_val, _ = sess.run([cost, W, b, train], 
                                         feed_dict={X: [1,2,3], Y: [1,2,3]})
    if step % 20 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 1.5568064 [0.26094753] [0.38600874]
# 20 0.059906203 [0.7048007] [0.54784054]
# 40 0.042131413 [0.7576302] [0.53923094]
# 60 0.038153082 [0.77273] [0.5155208]
# 80 0.034650244 [0.7837641] [0.49144867]
# 100 0.031469885 [0.7939601] [0.46836713]
# 120 0.02858144 [0.8036464] [0.44635698]
# 140 0.02595812 [0.81287456] [0.4253799]
# 160 0.023575604 [0.8216688] [0.40538868]
# 180 0.02141174 [0.8300497] [0.38633698]
# 200 0.019446498 [0.8380367] [0.36818057]
# 220 0.017661592 [0.8456484] [0.35087743]
# 240 0.016040556 [0.85290235] [0.33438748]
# 260 0.014568291 [0.8598155] [0.31867245]
# 280 0.013231157 [0.8664036] [0.303696]
# 300 0.012016732 [0.87268215] [0.28942344]
# 320 0.0109137995 [0.8786656] [0.2758216]
# 340 0.009912077 [0.8843679] [0.262859]
# 360 0.009002309 [0.8898023] [0.25050554]
# 380 0.008176046 [0.89498115] [0.23873268]
# 400 0.0074256086 [0.89991665] [0.22751305]
# 420 0.0067440644 [0.9046201] [0.21682079]
# 440 0.0061250664 [0.9091027] [0.20663103]
# 460 0.005562875 [0.91337454] [0.19692011]
# 480 0.005052296 [0.91744566] [0.18766558]
# 500 0.0045885774 [0.9213254] [0.17884597]
# 520 0.004167417 [0.92502284] [0.17044087]
# 540 0.0037849077 [0.9285466] [0.16243069]
# 560 0.0034375088 [0.9319046] [0.15479696]
# 580 0.0031220058 [0.93510485] [0.14752206]
# 600 0.0028354616 [0.9381546] [0.14058907]
# 620 0.0025752021 [0.94106114] [0.13398193]
# 640 0.0023388383 [0.943831] [0.12768528]
# 660 0.0021241691 [0.9464708] [0.12168452]
# 680 0.0019292136 [0.9489864] [0.11596581]
# 700 0.0017521358 [0.9513839] [0.11051583]
# 720 0.0015913189 [0.95366865] [0.10532202]
# 740 0.0014452641 [0.9558461] [0.10037225]
# 760 0.0013126087 [0.9579211] [0.09565514]
# 780 0.0011921327 [0.95989877] [0.09115966]
# 800 0.0010827159 [0.9617833] [0.08687549]
# 820 0.000983339 [0.96357936] [0.08279265]
# 840 0.0008930848 [0.965291] [0.07890172]
# 860 0.00081111566 [0.96692216] [0.07519364]
# 880 0.00073666935 [0.9684767] [0.07165981]
# 900 0.00066905515 [0.9699581] [0.06829215]
# 920 0.0006076441 [0.97137004] [0.06508268]
# 940 0.0005518735 [0.97271556] [0.06202399]
# 960 0.0005012203 [0.9739978] [0.0591091]
# 980 0.0004552165 [0.9752198] [0.05633119]
# 1000 0.0004134356 [0.9763844] [0.05368384]
# 1020 0.0003754889 [0.97749424] [0.05116089]
# 1040 0.00034102297 [0.97855186] [0.04875653]
# 1060 0.00030972593 [0.97955984] [0.04646518]
# 1080 0.0002812939 [0.98052055] [0.04428146]
# 1100 0.00025547863 [0.98143595] [0.04220037]
# 1120 0.00023202905 [0.9823084] [0.04021711]
# 1140 0.00021073385 [0.9831399] [0.03832706]
# 1160 0.00019139098 [0.9839322] [0.03652585]
# 1180 0.00017382298 [0.9846873] [0.03480927]
# 1200 0.00015786836 [0.985407] [0.03317335]
# 1220 0.0001433794 [0.9860928] [0.03161431]
# 1240 0.0001302196 [0.9867464] [0.03012856]
# 1260 0.00011826784 [0.9873693] [0.02871262]
# 1280 0.000107412176 [0.98796284] [0.02736325]
# 1300 9.755421e-05 [0.98852855] [0.0260773]
# 1320 8.859927e-05 [0.9890676] [0.02485177]
# 1340 8.046921e-05 [0.9895813] [0.02368385]
# 1360 7.308392e-05 [0.990071] [0.02257092]
# 1380 6.637405e-05 [0.9905377] [0.02151011]
# 1400 6.0282426e-05 [0.9909824] [0.02049917]
# 1420 5.4749544e-05 [0.9914062] [0.01953577]
# 1440 4.972328e-05 [0.99181014] [0.01861763]
# 1460 4.5160577e-05 [0.992195] [0.01774265]
# 1480 4.101475e-05 [0.9925618] [0.01690879]
# 1500 3.7250324e-05 [0.99291134] [0.01611414]
# 1520 3.3831766e-05 [0.99324447] [0.01535685]
# 1540 3.0726307e-05 [0.993562] [0.01463514]
# 1560 2.7906617e-05 [0.99386454] [0.01394734]
# 1580 2.5345158e-05 [0.9941529] [0.01329185]
# 1600 2.3018625e-05 [0.9944277] [0.01266719]
# 1620 2.0906102e-05 [0.9946895] [0.01207189]
# 1640 1.8987063e-05 [0.9949392] [0.01150454]
# 1660 1.7244281e-05 [0.995177] [0.01096384]
# 1680 1.5661613e-05 [0.9954037] [0.01044856]
# 1700 1.4223841e-05 [0.9956197] [0.00995751]
# 1720 1.2917945e-05 [0.9958256] [0.00948951]
# 1740 1.1732857e-05 [0.99602175] [0.00904354]
# 1760 1.0655564e-05 [0.99620867] [0.00861853]
# 1780 9.677494e-06 [0.9963868] [0.0082135]
# 1800 8.789392e-06 [0.9965567] [0.00782751]
# 1820 7.982582e-06 [0.9967185] [0.00745963]
# 1840 7.2499956e-06 [0.9968727] [0.00710904]
# 1860 6.584843e-06 [0.9970197] [0.00677494]
# 1880 5.9800586e-06 [0.9971598] [0.00645654]
# 1900 5.4313587e-06 [0.99729323] [0.00615312]
# 1920 4.9326654e-06 [0.99742043] [0.00586394]
# 1940 4.4802664e-06 [0.99754167] [0.00558836]
# 1960 4.0691366e-06 [0.9976572] [0.00532574]
# 1980 3.6952567e-06 [0.99776727] [0.00507544]
# 2000 3.3562212e-06 [0.9978722] [0.00483693]

# %% [markdown]
# # Testing our model

# %%
print(sess.run(hypothesis, feed_dict={X: [5]}))
print(sess.run(hypothesis, feed_dict={X: [2.5]}))
print(sess.run(hypothesis, feed_dict={X: [1.5, 3.5]}))
# Out:
# [4.9942117]
# [2.4995186]
# [1.5016413 3.497396 ]

# %% [markdown]
# # Fit the line with new training data

# %%
for step in range(2001):
    cost_val, W_val, b_val, _ = \
        sess.run([cost, W, b, train], 
                 feed_dict={X: [1, 2, 3, 4, 5],
                            Y: [2.1, 3.1, 4.1, 5.1, 6.1]})
    if step % 200 == 0:
        print(step, cost_val, W_val, b_val)
# Out:
# 0 0.53376645 [1.1143513] [0.04447575]
# 200 0.04788462 [1.1420679] [0.5870896]
# 400 0.012355658 [1.0721657] [0.8394586]
# 600 0.0031881526 [1.0366579] [0.9676533]
# 800 0.0008226473 [1.0186211] [1.0327717]
# 1000 0.0002122663 [1.0094588] [1.0658503]
# 1200 5.476949e-05 [1.0048047] [1.0826533]
# 1400 1.4133334e-05 [1.0024408] [1.0911881]
# 1600 3.6477868e-06 [1.00124] [1.0955232]
# 1800 9.417275e-07 [1.0006301] [1.0977254]
# 2000 2.433122e-07 [1.0003203] [1.0988439]

# %% [markdown]
# # Testing our model

# %%
print(sess.run(hypothesis, feed_dict={X: [5]}))
print(sess.run(hypothesis, feed_dict={X: [2.5]}))
print(sess.run(hypothesis, feed_dict={X: [1.5, 3.5]}))
# Out:
# [6.1004443]
# [3.599646]
# [2.5993266 4.599965 ]
